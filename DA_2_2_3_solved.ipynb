# %% [markdown]
# # Module: Communicating Analysis Results
# ## Sprint: PowerPoint / Soft skills
# ## Part 3: Graded Task Both Topics
#
# Tips and example of project solution can be found [here](https://docs.google.com/document/d/1WyqQuxRd5loXJbBSGW6ixaI0xwY32mb71pew9pCuZ8Q/edit?usp=sharing)
